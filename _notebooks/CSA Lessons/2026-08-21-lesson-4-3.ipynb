# %%
---
layout: post
toc: true
codemirror: true
title: Lesson 4.3
description: N/A
permalink: /csalessons/lesson4-3s
---

# %% [markdown]
# # Array Creation and Access
#
# ## Intro into Arrays
# * An **array** is a data structure used to implement a collection (list) of primitive or object reference data.
# * An **element** is a single value in the array.
# * The **index** of an element is the position of the element in the array.
#   * In Java, the first element of an array is at index `0`.
# * The **length** of an array is the number of elements in the array.
#   * `length` is a `public final` data member of an array.
#   * Since `length` is `public`, it can be accessed in any class.
#   * Since `length` is `final`, an array's length cannot be changed after creation.
# * In Java, the last element of an array named `list` is at index `list.length - 1`.
#
# ---
#
# ## A Look into List Memory
#
# ```java
# int[] listOne = new int[5];

# %% [markdown]
# int[] listOne = new int[5];     // [0, 0, 0, 0, 0]
# listOne[2] = 33;                // [0, 0, 33, 0, 0]
# listOne[3] = listOne[2] * 3;    // [0, 0, 33, 99, 0]
#
# try {
#     listOne[5] = 13; // Throws error: index 5 out of bounds for length 5
# } catch (Exception e) {
#     System.out.println("Error at listOne[5] = 13");
#     System.out.println("ArrayIndexOutOfBoundsException: We can't access a memory index that doesn't exist!");
# }
#
# System.out.println(listOne);    // Prints memory reference: [I@620c6ceb
# System.out.println(listOne[4]); // Prints value at index 4: 0

# %% [markdown]
# // Example Student class for reference
# class Student {
#     String name;
#     Student(String name) { this.name = name; }
#     @Override
#     public String toString() { return name; }
# }
#
# Student[] students = {
#     new Student("Alice"),
#     new Student("Bob"),
#     new Student("Charlie")
# };
#
# // 1) Traditional for loop
# System.out.println("--- For Loop ---");
# for (int i = 0; i < students.length; i++) {
#     System.out.println(students[i]);
# }
#
# // 2) While loop
# System.out.println("--- While Loop ---");
# int index = 0;
# while (index < students.length) {
#     System.out.println(students[index]);
#     index++;
# }
